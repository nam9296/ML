# %%
import pandas as pd

# %%
pd.read_excel("./files/kto_201001.xlsx")
# Out:
#    2010년 01월 외래객 입국-목적별/국적별 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        국적         관광         상용         공용      유학/연수
# 1                      아시아주     329131      18238        421       4339
# 2                        일본     202825       1750         89        549
# 3                        대만      35788         41         17         37
# 4                        홍콩      13874         55          0         21
# ..                      ...        ...        ...        ...        ...
# 67                       교포          0          0          0          0
# 68                        계     400818      22896       2738       5118
# 69                     전년동기     441688      20545       2764       4876
# 70                   성장률(%)       -9.3       11.4       -0.9          5
# 71                   구성비(%)       70.4          4        0.5        0.9
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %% [markdown]
# - .은 현재 디렉토리를 의미한다
# - ./은 Pythonwork폴더 밑에 files폴더 밑에 kto_201001.xlsx 파일 열기

# %%
pd.read_excel("./files/kto_201001.xlsx",
             header=1)
# Out:
#           국적        관광       상용     공용   유학/연수       기타         계      전년동기  \
# 0       아시아주  329131.0  18238.0  421.0  4339.0  80916.0  433045.0  474653.0
# 1         일본  202825.0   1750.0   89.0   549.0   3971.0  209184.0  237816.0
# 2         대만   35788.0     41.0   17.0    37.0    516.0   36399.0   37425.0
# 3         홍콩   13874.0     55.0    0.0    21.0    595.0   14545.0   25207.0
# 4        마카오     554.0      0.0    0.0     0.0      0.0     554.0     955.0
# ..       ...       ...      ...    ...     ...      ...       ...       ...
# 61  남아프리카공화국     214.0     27.0    0.0     2.0    545.0     788.0     640.0
# 62   아프리카 기타     349.0    594.0   25.0    86.0    296.0    1350.0    1294.0
# 63      기타대륙      10.0      3.0    0.0     0.0      0.0      13.0      20.0
# 64      국적미상      10.0      3.0    0.0     0.0      0.0      13.0      20.0
# 65      교포소계       0.0      0.0    0.0     0.0  22537.0   22537.0   18438.0
#
#     성장률(%)  구성비(%)
# 0     -8.8    76.0
# ...

# %% [markdown]
# 밑에 4줄을 지우자

# %%
pd.read_excel("./files/kto_201001.xlsx",
             header=1,
             skipfooter =4)
# Out:
#          국적      관광     상용   공용  유학/연수     기타       계    전년동기  성장률(%)  구성비(%)
# 0      아시아주  329131  18238  421   4339  80916  433045  474653    -8.8    76.0
# 1        일본  202825   1750   89    549   3971  209184  237816   -12.0    36.7
# 2        대만   35788     41   17     37    516   36399   37425    -2.7     6.4
# 3        홍콩   13874     55    0     21    595   14545   25207   -42.3     2.6
# 4       마카오     554      0    0      0      0     554     955   -42.0     0.1
# ..      ...     ...    ...  ...    ...    ...     ...     ...     ...     ...
# 62  아프리카 기타     349    594   25     86    296    1350    1294     4.3     0.2
# 63     기타대륙      10      3    0      0      0      13      20   -35.0     0.0
# 64     국적미상      10      3    0      0      0      13      20   -35.0     0.0
# 65     교포소계       0      0    0      0  22537   22537   18438    22.2     4.0
# 66       교포       0      0    0      0  22537   22537   18438    22.2     4.0
#
# [67 rows x 10 columns]

# %%
# pd.read_excel("./files/kto_201001.xlsx",
#              header=1,
#              skiprows=1, 
#              skipfooter =4)

# %% [markdown]
# 6개의 열만 읽고싶다

# %%
kto_201001=pd.read_excel("./files/kto_201001.xlsx",
             header=1,
              usecols='A:G',
             skipfooter =4)
kto_201001
# Out:
#          국적      관광     상용   공용  유학/연수     기타       계
# 0      아시아주  329131  18238  421   4339  80916  433045
# 1        일본  202825   1750   89    549   3971  209184
# 2        대만   35788     41   17     37    516   36399
# 3        홍콩   13874     55    0     21    595   14545
# 4       마카오     554      0    0      0      0     554
# ..      ...     ...    ...  ...    ...    ...     ...
# 62  아프리카 기타     349    594   25     86    296    1350
# 63     기타대륙      10      3    0      0      0      13
# 64     국적미상      10      3    0      0      0      13
# 65     교포소계       0      0    0      0  22537   22537
# 66       교포       0      0    0      0  22537   22537
#
# [67 rows x 7 columns]

# %%
kto_201001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201001.describe()
# Out:
#                   관광            상용           공용        유학/연수            기타  \
# count      67.000000     67.000000    67.000000    67.000000     67.000000
# mean    11964.716418    683.462687    81.731343   152.776119   4115.910448
# std     47055.349998   2639.234303   370.034666   622.299519  11560.294887
# min         0.000000      0.000000     0.000000     0.000000      0.000000
# 25%       254.000000     23.500000     0.000000     6.000000    161.500000
# 50%       554.000000     47.000000     2.000000    17.000000    449.000000
# 75%      3638.000000    301.000000    14.000000    54.500000   1608.000000
# max    329131.000000  18238.000000  2159.000000  4339.000000  80916.000000
#
#                    계
# count      67.000000
# mean    16998.597015
# std     59189.624627
# min        13.000000
# 25%       605.000000
# 50%      1350.000000
# 75%      7582.000000
# max    433045.000000

# %% [markdown]
# 각 컬럼값이 0인 값을 추출

# %%
kto_201001[(kto_201001['관광']==0) | (kto_201001['상용']==0)| (kto_201001['공용']==0)| (kto_201001['유학/연수']==0)]
# Out:
#           국적     관광   상용  공용  유학/연수     기타      계
# 3         홍콩  13874   55   0     21    595  14545
# 4        마카오    554    0   0      0      0    554
# 6      말레이시아   3292   61   0     49   1157   4559
# 16      캄보디아    102   22   0     25    131    280
# 19        이란     69  309   0      3    217    598
# 20      이스라엘    792   11   0      0     53    856
# 24       GCC    223  134   0     18     55    430
# 38       스위스    512   30   0      7     77    626
# 40       덴마크    378   28   0      5     94    505
# 41      노르웨이    517  274   0      6    149    946
# 45       그리스    345   47   0      0    213    605
# 46      포르투갈    256    9   0      1     44    310
# 47       핀란드    376   16   0     12    131    535
# 48      아일랜드    311   16   0      1    198    526
# 49     우크라이나    386   29   0      6   1515   1936
# 51     크로아티아    166   20   0      1    298    485
# 52      루마니아    142   12   0      9    370    533
# 53      불가리아    103    0   0      9    414    526
# ...

# %%
kto_201001['기준년월']='2010-01'
kto_201001
# Out:
#          국적      관광     상용   공용  유학/연수     기타       계     기준년월
# 0      아시아주  329131  18238  421   4339  80916  433045  2010-01
# 1        일본  202825   1750   89    549   3971  209184  2010-01
# 2        대만   35788     41   17     37    516   36399  2010-01
# 3        홍콩   13874     55    0     21    595   14545  2010-01
# 4       마카오     554      0    0      0      0     554  2010-01
# ..      ...     ...    ...  ...    ...    ...     ...      ...
# 62  아프리카 기타     349    594   25     86    296    1350  2010-01
# 63     기타대륙      10      3    0      0      0      13  2010-01
# 64     국적미상      10      3    0      0      0      13  2010-01
# 65     교포소계       0      0    0      0  22537   22537  2010-01
# 66       교포       0      0    0      0  22537   22537  2010-01
#
# [67 rows x 8 columns]

# %%
kto_201001['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %% [markdown]
# 대륙 리스트

# %%
continents_list=['아시아주','미주','구주','대양주','아프리카주','기타대륙','소포소계']
continents_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '소포소계']

# %%
kto_201001['국적']
# Out:
# 0        아시아주
# 1          일본
# 2          대만
# 3          홍콩
# 4         마카오
#        ...
# 62    아프리카 기타
# 63       기타대륙
# 64       국적미상
# 65       교포소계
# 66         교포
# Name: 국적, Length: 67, dtype: object

# %%
kto_201001[kto_201001['국적'].isin(continents_list)]
# Out:
#        국적      관광     상용    공용  유학/연수     기타       계     기준년월
# 0    아시아주  329131  18238   421   4339  80916  433045  2010-01
# 26     미주   33067   1391  2159    200  17022   53839  2010-01
# 32     구주   28798   2250   119    476  14866   46509  2010-01
# 56    대양주    9249    393    14     15   1701   11372  2010-01
# 60  아프리카주     563    621    25     88    841    2138  2010-01
# 63   기타대륙      10      3     0      0      0      13  2010-01

# %%
kto_201001[kto_201001['국적'].isin(continents_list)==False]
# Out:
#           국적      관광    상용  공용  유학/연수     기타       계     기준년월
# 1         일본  202825  1750  89    549   3971  209184  2010-01
# 2         대만   35788    41  17     37    516   36399  2010-01
# 3         홍콩   13874    55   0     21    595   14545  2010-01
# 4        마카오     554     0   0      0      0     554  2010-01
# 5         태국   13374    39  13     53   4335   17814  2010-01
# ..       ...     ...   ...  ..    ...    ...     ...      ...
# 61  남아프리카공화국     214    27   0      2    545     788  2010-01
# 62   아프리카 기타     349   594  25     86    296    1350  2010-01
# 64      국적미상      10     3   0      0      0      13  2010-01
# 65      교포소계       0     0   0      0  22537   22537  2010-01
# 66        교포       0     0   0      0  22537   22537  2010-01
#
# [61 rows x 8 columns]

# %%
kto201001_country=kto_201001[kto_201001['국적'].isin(continents_list)==False]
kto201001_country
# Out:
#           국적      관광    상용  공용  유학/연수     기타       계     기준년월
# 1         일본  202825  1750  89    549   3971  209184  2010-01
# 2         대만   35788    41  17     37    516   36399  2010-01
# 3         홍콩   13874    55   0     21    595   14545  2010-01
# 4        마카오     554     0   0      0      0     554  2010-01
# 5         태국   13374    39  13     53   4335   17814  2010-01
# ..       ...     ...   ...  ..    ...    ...     ...      ...
# 61  남아프리카공화국     214    27   0      2    545     788  2010-01
# 62   아프리카 기타     349   594  25     86    296    1350  2010-01
# 64      국적미상      10     3   0      0      0      13  2010-01
# 65      교포소계       0     0   0      0  22537   22537  2010-01
# 66        교포       0     0   0      0  22537   22537  2010-01
#
# [61 rows x 8 columns]

# %%
kto_201001_country_newindex=kto201001_country.reset_index(drop=True)
kto_201001_country_newindex.tail(30)
# Out:
#           국적    관광   상용  공용  유학/연수     기타      계     기준년월
# 31        독일  5838  255  24     68   1458   7643  2010-01
# 32       프랑스  3019  343  44    115   1145   4666  2010-01
# 33      네덜란드  1205   47   1     20    449   1722  2010-01
# 34       스웨덴   579   63   5     17    185    849  2010-01
# 35       스위스   512   30   0      7     77    626  2010-01
# 36      이탈리아  1157   40  12     12    155   1376  2010-01
# 37       덴마크   378   28   0      5     94    505  2010-01
# 38      노르웨이   517  274   0      6    149    946  2010-01
# 39       벨기에   322   25   1      8    104    460  2010-01
# 40     오스트리아   440   13   2      9    141    605  2010-01
# 41       스페인   542   29  11      8    108    698  2010-01
# 42       그리스   345   47   0      0    213    605  2010-01
# 43      포르투갈   256    9   0      1     44    310  2010-01
# 44       핀란드   376   16   0     12    131    535  2010-01
# 45      아일랜드   311   16   0      1    198    526  2010-01
# ...

# %% [markdown]
# 대륙열을 만들어서 0번부터 번까지 아시아를 입력하고싶다

# %%
continents=['아시아']*25+['아메리카']*5+['유럽']*23+['오세아니아']*3+['아프리카']*2+['기타대륙']+['교포']*2
continents
# Out:
# ['아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '오세아니아',
#  '오세아니아',
#  '오세아니아',
#  '아프리카',
#  '아프리카',
#  '기타대륙',
#  '교포',
#  '교포']

# %%
kto_201001_country_newindex['대륙']=continents
kto_201001_country_newindex
# Out:
#           국적      관광    상용  공용  유학/연수     기타       계     기준년월    대륙
# 0         일본  202825  1750  89    549   3971  209184  2010-01   아시아
# 1         대만   35788    41  17     37    516   36399  2010-01   아시아
# 2         홍콩   13874    55   0     21    595   14545  2010-01   아시아
# 3        마카오     554     0   0      0      0     554  2010-01   아시아
# 4         태국   13374    39  13     53   4335   17814  2010-01   아시아
# ..       ...     ...   ...  ..    ...    ...     ...      ...   ...
# 56  남아프리카공화국     214    27   0      2    545     788  2010-01  아프리카
# 57   아프리카 기타     349   594  25     86    296    1350  2010-01  아프리카
# 58      국적미상      10     3   0      0      0      13  2010-01  기타대륙
# 59      교포소계       0     0   0      0  22537   22537  2010-01    교포
# 60        교포       0     0   0      0  22537   22537  2010-01    교포
#
# [61 rows x 9 columns]

# %%
kto_201001_country_newindex['관광객비율(%)']= round(kto_201001_country_newindex['관광']/kto_201001_country_newindex['계']*100,1)
kto_201001_country_newindex
# Out:
#           국적      관광    상용  공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)
# 0         일본  202825  1750  89    549   3971  209184  2010-01   아시아      97.0
# 1         대만   35788    41  17     37    516   36399  2010-01   아시아      98.3
# 2         홍콩   13874    55   0     21    595   14545  2010-01   아시아      95.4
# 3        마카오     554     0   0      0      0     554  2010-01   아시아     100.0
# 4         태국   13374    39  13     53   4335   17814  2010-01   아시아      75.1
# ..       ...     ...   ...  ..    ...    ...     ...      ...   ...       ...
# 56  남아프리카공화국     214    27   0      2    545     788  2010-01  아프리카      27.2
# 57   아프리카 기타     349   594  25     86    296    1350  2010-01  아프리카      25.9
# 58      국적미상      10     3   0      0      0      13  2010-01  기타대륙      76.9
# 59      교포소계       0     0   0      0  22537   22537  2010-01    교포       0.0
# 60        교포       0     0   0      0  22537   22537  2010-01    교포       0.0
#
# [61 rows x 10 columns]

# %%
kto_201001_country_newindex.sort_values(by='관광객비율(%)',ascending=False)
# Out:
#       국적      관광    상용  공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)
# 3    마카오     554     0   0      0      0     554  2010-01  아시아     100.0
# 1     대만   35788    41  17     37    516   36399  2010-01  아시아      98.3
# 0     일본  202825  1750  89    549   3971  209184  2010-01  아시아      97.0
# 2     홍콩   13874    55   0     21    595   14545  2010-01  아시아      95.4
# 19  이스라엘     792    11   0      0     53     856  2010-01  아시아      92.5
# ..   ...     ...   ...  ..    ...    ...     ...      ...  ...       ...
# 18    이란      69   309   0      3    217     598  2010-01  아시아      11.5
# 13  파키스탄      70   200   1     41    402     714  2010-01  아시아       9.8
# 12  스리랑카      39    28   2     13    566     648  2010-01  아시아       6.0
# 59  교포소계       0     0   0      0  22537   22537  2010-01   교포       0.0
# 60    교포       0     0   0      0  22537   22537  2010-01   교포       0.0
#
# [61 rows x 10 columns]

# %% [markdown]
# Quiz1
# - 대륙별 관광객 비율

# %%
kto_201001_country_newindex.groupby('대륙').mean()[['관광객비율(%)']]
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   76.900000
# 아메리카   60.760000
# 아시아    49.544000
# 아프리카   26.550000
# 오세아니아  79.733333
# 유럽     60.926087

# %%
kto_201001_country_newindex.groupby('대륙')['관광객비율(%)'].mean()
# Out:
# 대륙
# 교포        0.000000
# 기타대륙     76.900000
# 아메리카     60.760000
# 아시아      49.544000
# 아프리카     26.550000
# 오세아니아    79.733333
# 유럽       60.926087
# Name: 관광객비율(%), dtype: float64

# %%
kto_201001_country_newindex.groupby('대륙')['관광'].sum()/kto_201001_country_newindex.groupby('대륙')['계'].sum()
# Out:
# 대륙
# 교포       0.000000
# 기타대륙     0.769231
# 아메리카     0.614183
# 아시아      0.760039
# 아프리카     0.263330
# 오세아니아    0.813313
# 유럽       0.619192
# dtype: float64

# %%
kto_201001_continents_sum = kto_201001_country_newindex.groupby(['대륙']).sum(['관광'])
round(kto_201001_continents_sum['관광']/kto_201001_continents_sum['계']*100,1)
# Out:
# 대륙
# 교포        0.0
# 기타대륙     76.9
# 아메리카     61.4
# 아시아      76.0
# 아프리카     26.3
# 오세아니아    81.3
# 유럽       61.9
# dtype: float64

# %%
kto_201001_country_newindex.groupby('대륙').apply(lambda x: ((x.관광.sum()/x.계.sum())*100).round(4))
kto_201001_country_newindex.pivot_table(values='관광객비율(%)', index='대륙')
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   76.900000
# 아메리카   60.760000
# 아시아    49.544000
# 아프리카   26.550000
# 오세아니아  79.733333
# 유럽     60.926087

# %%
kto_201001_country_newindex.pivot_table(values='관광객비율(%)', index='대륙',aggfunc='mean')
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   76.900000
# 아메리카   60.760000
# 아시아    49.544000
# 아프리카   26.550000
# 오세아니아  79.733333
# 유럽     60.926087

# %%
kto_201001_country_newindex[kto_201001_country_newindex['국적']=='중국']
# Out:
#     국적     관광     상용  공용  유학/연수     기타      계     기준년월   대륙  관광객비율(%)
# 17  중국  40425  11930  55   2751  36091  91252  2010-01  아시아      44.3

# %%
tourist_sum=kto_201001_country_newindex['관광'].sum()
tourist_sum
# Out:
# 400818

# %%
kto_201001_country_newindex
# Out:
#           국적      관광    상용  공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)
# 0         일본  202825  1750  89    549   3971  209184  2010-01   아시아      97.0
# 1         대만   35788    41  17     37    516   36399  2010-01   아시아      98.3
# 2         홍콩   13874    55   0     21    595   14545  2010-01   아시아      95.4
# 3        마카오     554     0   0      0      0     554  2010-01   아시아     100.0
# 4         태국   13374    39  13     53   4335   17814  2010-01   아시아      75.1
# ..       ...     ...   ...  ..    ...    ...     ...      ...   ...       ...
# 56  남아프리카공화국     214    27   0      2    545     788  2010-01  아프리카      27.2
# 57   아프리카 기타     349   594  25     86    296    1350  2010-01  아프리카      25.9
# 58      국적미상      10     3   0      0      0      13  2010-01  기타대륙      76.9
# 59      교포소계       0     0   0      0  22537   22537  2010-01    교포       0.0
# 60        교포       0     0   0      0  22537   22537  2010-01    교포       0.0
#
# [61 rows x 10 columns]

# %%
kto_201001_country_newindex['전체비율(%)']=round(kto_201001_country_newindex['관광']/tourist_sum*100,1)
kto_201001_country_newindex
# Out:
#           국적      관광    상용  공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 0         일본  202825  1750  89    549   3971  209184  2010-01   아시아      97.0
# 1         대만   35788    41  17     37    516   36399  2010-01   아시아      98.3
# 2         홍콩   13874    55   0     21    595   14545  2010-01   아시아      95.4
# 3        마카오     554     0   0      0      0     554  2010-01   아시아     100.0
# 4         태국   13374    39  13     53   4335   17814  2010-01   아시아      75.1
# ..       ...     ...   ...  ..    ...    ...     ...      ...   ...       ...
# 56  남아프리카공화국     214    27   0      2    545     788  2010-01  아프리카      27.2
# 57   아프리카 기타     349   594  25     86    296    1350  2010-01  아프리카      25.9
# 58      국적미상      10     3   0      0      0      13  2010-01  기타대륙      76.9
# 59      교포소계       0     0   0      0  22537   22537  2010-01    교포       0.0
# 60        교포       0     0   0      0  22537   22537  2010-01    교포       0.0
#
#     전체비율(%)
# 0      50.6
# ...

# %%
kto_201001_country_newindex.sort_values('전체비율(%)',ascending=False)
# Out:
#         국적      관광     상용    공용  유학/연수     기타       계     기준년월    대륙  \
# 0       일본  202825   1750    89    549   3971  209184  2010-01   아시아
# 17      중국   40425  11930    55   2751  36091   91252  2010-01   아시아
# 1       대만   35788     41    17     37    516   36399  2010-01   아시아
# 25      미국   26943   1195  2145    135  12647   43065  2010-01  아메리카
# 2       홍콩   13874     55     0     21    595   14545  2010-01   아시아
# ..     ...     ...    ...   ...    ...    ...     ...      ...   ...
# 18      이란      69    309     0      3    217     598  2010-01   아시아
# 21  우즈베키스탄     190    293    17     40    740    1280  2010-01   아시아
# 49    루마니아     142     12     0      9    370     533  2010-01    유럽
# 48   크로아티아     166     20     0      1    298     485  2010-01    유럽
# 60      교포       0      0     0      0  22537   22537  2010-01    교포
#
#     관광객비율(%)  전체비율(%)
# 0       97.0     50.6
# 17      44.3     10.1
# 1       98.3      8.9
# 25      62.6      6.7
# ...

# %% [markdown]
# ## 데이터 전처리 과정 함수 정의

# %%
create_kto_data(2020,1)

# %%
for yy in range(2010,2021):
    for mm in range(1,13):
        yymm="{}{}".format(yy,mm)
        print(yymm)
# Out:
# 20101
# 20102
# 20103
# 20104
# 20105
# 20106
# 20107
# 20108
# 20109
# 201010
# 201011
# 201012
# 20111
# 20112
# 20113
# 20114
# 20115
# 20116
# 20117
# 20118
# 20119
# 201110
# 201111
# 201112
# 20121
# 20122
# 20123
# 20124
# 20125
# 20126
# 20127
# 20128
# 20129
# 201210
# 201211
# 201212
# 20131
# 20132
# 20133
# 20134
# 20135
# 20136
# 20137
# 20138
# 20139
# 201310
# 201311
# 201312
# 20141
# 20142
# 20143
# 20144
# 20145
# 20146
# 20147
# 20148
# 20149
# 201410
# 201411
# 201412
# 20151
# 20152
# 20153
# 20154
# 20155
# 20156
# 20157
# 20158
# 20159
# 201510
# 201511
# 201512
# 20161
# 20162
# 20163
# 20164
# 20165
# 20166
# 20167
# 20168
# 20169
# 201610
# 201611
# 201612
# 20171
# 20172
# 20173
# 20174
# 20175
# 20176
# 20177
# 20178
# 20179
# 201710
# 201711
# 201712
# 20181
# 20182
# 20183
# 20184
# 20185
# 20186
# 20187
# 20188
# 20189
# 201810
# 201811
# 201812
# 20191
# 20192
# 20193
# 20194
# 20195
# 20196
# 20197
# 20198
# 20199
# 201910
# 201911
# 201912
# 20201
# ...

# %%
for yy in range(2010,2021):
    for mm in range(1,13):
        mms=str(mm).zfill(2)
        yymm="{}{}".format(yy,mms)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
def create_kto_data(yy, mm):
    # 엑셀데이터 불러오기
    mms=str(mm).zfill(2)
    file_path="./files/kto_{}{}.xlsx" .format(yy, mms)
    
    df=pd.read_excel(file_path,header=1, skipfooter = 4, usecols = 'A:G')
    
    # 년월컬럼 추가
    df['기준년월'] = '{}-{}'.format(yy, mms)
    
    # 대륙을 제거하고 국가만 남기기
    ignore_list = ['아시아주', '구주', '아프리카주', '미주', '대양주', '기타대륙', '교포소계']
    condition = (df['국적'].isin(ignore_list) == False) #대륙정보 미포함 조건
    df_country = df[condition].reset_index(drop = True) #대륙정보 제거    
    
    # 대륙 칼럼
    continents = ['아시아']*25 + ['아메리카']*5 + ['유럽']*23 + ['오세아니아']*3 + ['아프리카']*2 + ['기타대륙']*1 + ['교포']*1
    df_country['대륙'] = continents    
    
    # 관광객 비율
    df_country['관광객비율(%)'] = \
        round(df_country['관광'] / df_country['계'] * 100, 1)    
    
    # 전체 비율
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = \
        round(df_country['관광'] / tourist_sum * 100, 1)    
    
    return(df_country)

# %%
create_kto_data(2020,1)
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  194840  2804   141   1035   5149  203969  2020-01    아시아
# 1         대만  108623    95    20    285   1331  110354  2020-01    아시아
# 2         홍콩   65837    51     8    171    895   66962  2020-01    아시아
# 3        마카오    5312     4     0     14     17    5347  2020-01    아시아
# 4         태국   31232    44   110    126   6954   38466  2020-01    아시아
# 5      말레이시아   24541   101     1    139   2767   27549  2020-01    아시아
# 6        필리핀   15002   155   169    211  15165   30702  2020-01    아시아
# 7      인도네시아   14336    98    46    231   4732   19443  2020-01    아시아
# 8       싱가포르    9157    80     7     54   1440   10738  2020-01    아시아
# 9        미얀마    1273     9    47     98   4227    5654  2020-01    아시아
# 10       베트남   18058   747    54   3122   8251   30232  2020-01    아시아
# 11        인도    2391  2094    56    166   4542    9249  2020-01    아시아
# ...

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for yy in range(2010, 2020):
    for mm in range(1, 13):
        temp = create_kto_data(yy,mm)
        #print(temp)
        df=df.append(temp,ignore_index=True)

# %%
df.to_excel("./files/kto_total.xlsx",index=False)

# %%
df_filter=df[df['국적']=='중국']

# %%
df_filter.to_excel("[국적별 관광객데이터]중국.xlsx",index=False)

# %%
df_filter
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137   중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197   중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257   중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ...   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 6917  중국  451570   3625  388  44291  78238  578112  2019-08  아시아      78.1
# 6977  중국  432018   3873  447  25545  79467  541350  2019-09  아시아      79.8
# 7037  중국  476460   3967  547  12722  73999  567695  2019-10  아시아      83.9
# 7097  중국  426849   4020  545  12822  61133  505369  2019-11  아시아      84.5
# 7157  중국  433577   3951  682  13284  57383  508877  2019-12  아시아      85.2
#
#       전체비율(%)
# 17       10.1
# 77       13.6
# 137       9.2
# ...

# %%
country_list=df['국적'].unique()

# %%
for c in country_list:
    df_filter=df[df['국적']==c]
    df_filter
    
    file_path='./files/[국적별 관광객 데이터]{}.xlsx'.format(c)
    df_filter.to_excel(file_path, index=False)

# %% [markdown]
# 시계열 데이터 그래프 그리기

# %%
df=pd.read_excel("./files/kto_total.xlsx")
df
# Out:
#             국적      관광    상용  공용  유학/연수    기타       계     기준년월     대륙  \
# 0           일본  202825  1750  89    549  3971  209184  2010-01    아시아
# 1           대만   35788    41  17     37   516   36399  2010-01    아시아
# 2           홍콩   13874    55   0     21   595   14545  2010-01    아시아
# 3          마카오     554     0   0      0     0     554  2010-01    아시아
# 4           태국   13374    39  13     53  4335   17814  2010-01    아시아
# ...        ...     ...   ...  ..    ...   ...     ...      ...    ...
# 7195    대양주 기타     154     2   4      0    92     252  2019-12  오세아니아
# 7196  남아프리카공화국     665     3   0      3   251     922  2019-12   아프리카
# 7197   아프리카 기타    1273   644  66     93  1002    3078  2019-12   아프리카
# 7198      국적미상      36     1   0      0    10      47  2019-12   기타대륙
# 7199        교포       0     0   0      0  5281    5281  2019-12     교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# 3        100.0      0.1
# ...

# %%
from matplotlib import font_manager, rc
import platform 

if platform.system() == 'Windows': 
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else: 
    print('Check your OS system')

# %%
import matplotlib.pyplot as plt

# %%
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)
# 17      10.1
# 77      13.6
# 137      9.2
# 197     15.5
# 257     17.0

# %%
plt.plot(df_filter['기준년월'], df_filter['관광'])
plt.show()

# %%
plt.figure(figsize = (12, 4))
plt.plot(df_filter['기준년월'], df_filter['관광'])
plt.title('중국 국적의 관광객 추이')
plt.xlabel('기준년월')
plt.ylabel('관광객수')
plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])
plt.show()

# %%
cntry_list = ['중국', '일본', '대만', '미국', '홍콩']

# %%
for cntry in cntry_list:
    condition = (df['국적'] == cntry) #국적 관광객만 호출
    df_filter = df[condition]


    plt.figure(figsize = (12, 4))
    plt.plot(df_filter['기준년월'], df_filter['관광'])
    plt.title('{} 국적의 관광객 추이'.format(cntry))
    plt.xlabel('기준년월')
    plt.ylabel('관광객수')
    plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])
    plt.show()

# %%
df=pd.DataFrame({'email':['   test@naver.com', 
                            'sample@NAVER.COM   ', 
                            '   abc@yahoo.co.kr    ']})
df
# Out:
#                     email
# 0          test@naver.com
# 1     sample@NAVER.COM
# 2     abc@yahoo.co.kr

# %%
df.email
# Out:
# 0            test@naver.com
# 1       sample@NAVER.COM
# 2       abc@yahoo.co.kr
# Name: email, dtype: object

# %%
s='  hello'
print(s)
print(s.lstrip())
# lstrip, rstrip strip으로 공백 제거
# Out:
#   hello
# hello

# %%
# df.email.lstrip()  # 에러가 나옴

df.email.str.lstrip()
# Out:
# 0         test@naver.com
# 1    sample@NAVER.COM
# 2    abc@yahoo.co.kr
# Name: email, dtype: object

# %%
df.email.str.strip()
# Out:
# 0      test@naver.com
# 1    sample@NAVER.COM
# 2     abc@yahoo.co.kr
# Name: email, dtype: object

# %%
df.email.str.split('@')
# Out:
# 0         [   test, naver.com]
# 1       [sample, NAVER.COM   ]
# 2    [   abc, yahoo.co.kr    ]
# Name: email, dtype: object

# %%
df=pd.read_excel("./files/kto_total.xlsx")
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
for i in df['기준년월']:
    print(i.split('-'))
# Out:
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ['2010', '01']
# ...

# %%
df['기준년월'].str.split('-')
# Out:
# 0       [2010, 01]
# 1       [2010, 01]
# 2       [2010, 01]
# 3       [2010, 01]
# 4       [2010, 01]
#            ...
# 7195    [2019, 12]
# 7196    [2019, 12]
# 7197    [2019, 12]
# 7198    [2019, 12]
# 7199    [2019, 12]
# Name: 기준년월, Length: 7200, dtype: object

# %%
df['년도']=df['기준년월'].str.slice(0,4)
df['월']=df['기준년월'].str.slice(5,7)
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1
#
#    전체비율(%)    년도   월
# 0     50.6  2010  01
# 1      8.9  2010  01
# 2      3.5  2010  01
# 3      0.1  2010  01
# 4      3.3  2010  01

# %%
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)    년도   월
# 17      10.1  2010  01
# 77      13.6  2010  02
# 137      9.2  2010  03
# 197     15.5  2010  04
# 257     17.0  2010  05

# %% [markdown]
# Quiz2

# %%
df_filter.pivot_table('관광', index='년도', columns='월')
# Out:
# 월         01      02      03      04      05      06      07      08      09  \
# 년도
# 2010   40425   60590   50330   84252   89056   87080  122432  142180   93545
# 2011   55070   53863   72003   86397   85668  108060  170524  178937  144704
# 2012  106606   74895  110965  166843  154841  179074  258907  268988  203857
# 2013  148118  169395  182850  250549  196306  280319  417991  472005  353359
# 2014  230706  219533  313400  429419  410971  429991  540683  588181  423133
# 2015  327225  413096  386386  536428  517154  223101  172075  372990  453670
# 2016  456636  424232  500018  601460  614636  671493  823016  747818  611538
# 2017  489256  458952  263788  158784  172527  181507  207099  226153  229172
# 2018  236825  237075  281020  283533  284317  303405  332657  360982  326438
# 2019  320113  324291  369165  410542  413949  395196  439699  451570  432018
#
# 월         10      11      12
# 년도
# 2010  107237   75686   58987
# 2011  141824  113856  101605
# ...

# %%
pd.pivot_table(data=df_filter, index='년도',columns='월',values='관광')
# Out:
# 월         01      02      03      04      05      06      07      08      09  \
# 년도
# 2010   40425   60590   50330   84252   89056   87080  122432  142180   93545
# 2011   55070   53863   72003   86397   85668  108060  170524  178937  144704
# 2012  106606   74895  110965  166843  154841  179074  258907  268988  203857
# 2013  148118  169395  182850  250549  196306  280319  417991  472005  353359
# 2014  230706  219533  313400  429419  410971  429991  540683  588181  423133
# 2015  327225  413096  386386  536428  517154  223101  172075  372990  453670
# 2016  456636  424232  500018  601460  614636  671493  823016  747818  611538
# 2017  489256  458952  263788  158784  172527  181507  207099  226153  229172
# 2018  236825  237075  281020  283533  284317  303405  332657  360982  326438
# 2019  320113  324291  369165  410542  413949  395196  439699  451570  432018
#
# 월         10      11      12
# 년도
# 2010  107237   75686   58987
# 2011  141824  113856  101605
# ...

# %%
df_filter.set_index(['년도','월']).관광.unstack()
# Out:
# 월         01      02      03      04      05      06      07      08      09  \
# 년도
# 2010   40425   60590   50330   84252   89056   87080  122432  142180   93545
# 2011   55070   53863   72003   86397   85668  108060  170524  178937  144704
# 2012  106606   74895  110965  166843  154841  179074  258907  268988  203857
# 2013  148118  169395  182850  250549  196306  280319  417991  472005  353359
# 2014  230706  219533  313400  429419  410971  429991  540683  588181  423133
# 2015  327225  413096  386386  536428  517154  223101  172075  372990  453670
# 2016  456636  424232  500018  601460  614636  671493  823016  747818  611538
# 2017  489256  458952  263788  158784  172527  181507  207099  226153  229172
# 2018  236825  237075  281020  283533  284317  303405  332657  360982  326438
# 2019  320113  324291  369165  410542  413949  395196  439699  451570  432018
#
# 월         10      11      12
# 년도
# 2010  107237   75686   58987
# 2011  141824  113856  101605
# ...

# %%
df_pivot = df_filter.pivot_table(values = '관광'
                         , index = '년도'
                         , columns = '월')

df_pivot
# Out:
# 월         01      02      03      04      05      06      07      08      09  \
# 년도
# 2010   40425   60590   50330   84252   89056   87080  122432  142180   93545
# 2011   55070   53863   72003   86397   85668  108060  170524  178937  144704
# 2012  106606   74895  110965  166843  154841  179074  258907  268988  203857
# 2013  148118  169395  182850  250549  196306  280319  417991  472005  353359
# 2014  230706  219533  313400  429419  410971  429991  540683  588181  423133
# 2015  327225  413096  386386  536428  517154  223101  172075  372990  453670
# 2016  456636  424232  500018  601460  614636  671493  823016  747818  611538
# 2017  489256  458952  263788  158784  172527  181507  207099  226153  229172
# 2018  236825  237075  281020  283533  284317  303405  332657  360982  326438
# 2019  320113  324291  369165  410542  413949  395196  439699  451570  432018
#
# 월         10      11      12
# 년도
# 2010  107237   75686   58987
# 2011  141824  113856  101605
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(df_pivot,annot=True, fmt='.0f',cmap='rocket_r')

# %%
for cntry in cntry_list:
    condition = (df['국적'] == cntry) 
    df_filter = df[condition]
    # 피봇팅
    df_pivot = df_filter.pivot_table(values = '관광'
                         , index = '년도'
                         , columns = '월')
    
    plt.figure(figsize = (16, 10))
    sns.heatmap(df_pivot,annot=True, fmt='.0f',cmap='rocket_r')
    plt.title('{} 국적의 관광객 추이'.format(cntry))
