# %%
# 히스토그램

# %%
import seaborn as sns
import pandas as pd
import numpy as np
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
ax=plt.subplots()
sns.distplot(tips['total_bill'])

# %%
ax=plt.subplots()
sns.distplot(tips['total_bill'],kde=False)

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'])
ax.set_title("Total Bill Histogram")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Freq")
# Out:
# Text(0, 0.5, 'Freq')

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],rug=True) # rug 빈도를 출력 # rug 빈도를 출력
ax.set_title("Total Bill Histogram")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Freq")
# Out:
# Text(0, 0.5, 'Freq')

# %%
ax=plt.subplots()
ax=sns.countplot(tips['day']) # rug 빈도를 출력 # rug 빈도를 출력
# ax.set_title("Total Bill Histogram")
# ax.set_xlabel("Total Bill")
# ax.set_ylabel("Freq")

# %%
ax=plt.subplots()
ax=sns.countplot('day',data=tips)
ax.set_title('count of days')
ax.set_xlabel("day of the week")
ax.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
# 이변량 그래프
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips)
ax.set_title('scatterplot')
ax.set_xlabel("total bill")
ax.set_ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
# jointplot함수 내에서 자체적으로 plot 객체를 생성함
ax=sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
ax=sns.jointplot(x='total_bill',y='tip',data=tips, kind='hex')

# %%
#밀집도 그래프
ax=plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],data2=tips['tip'])

# %%
ax=plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],data2=tips['tip'],shade=True)

# %%
ax=plt.subplots()
ax=sns.barplot(x='time',y='total_bill',data=tips)
ax.set_title("bar plot")
ax.set_xlabel("time")
ax.set_ylabel("total bill")
# Out:
# Text(0, 0.5, 'total bill')

# %%
ax=plt.subplots()
ax=sns.boxplot(x='time',y='total_bill',data=tips)
ax.set_title("box plot")
ax.set_xlabel("time")
ax.set_ylabel("total bill")
# Out:
# Text(0, 0.5, 'total bill')

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title("violin plot")
ax.set_xlabel("time")
ax.set_ylabel("total bill")
# Out:
# Text(0, 0.5, 'total bill')

# %%
sns.pairplot(tips)

# %%
pairGrid=sns.PairGrid(tips)
pairGrid=pairGrid.map_upper(sns.regplot)
pairGrid=pairGrid.map_lower(sns.kdeplot)
pairGrid=pairGrid.map_diag(sns.distplot,rug=True)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg=False)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg=False,hue='sex')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg=False,hue='sex',
           scatter_kws={'s': 20})

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False, scatter_kws={'s':tips['size']*10}) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# matplotlib.org
# 들어가서 원하는거 복사해오면됨

# %%
plt.plot([1,4,9,16])
# plt.show() #이거 사용하면 정보가 안뜨고 그래프만 뜸

# %%
# %matplotlib inline
# 노트북 내부에 그림 출력

# %%
plt.title("plot")
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title("plot")
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
# 한글이 깨진다
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 라벨")
plt.ylabel("와이축 라벨")
plt.show()
# Out:
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 50641 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48296 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 50752 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 50641 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 48296 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 50752 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\82105\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# %%
# 한글이 깨진다
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 라벨")
plt.ylabel("와이축 라벨")
plt.show()

# %%
plt.title("'rs--' 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %%
# http://matplotlib.org/examples/color/named_colors.html

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="b", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="b", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
import numpy as np

# %%
np.linspace(-np.pi,np.pi,256)
# linspace(구간,구간,나눌갯수)
# Out:
# array([-3.14159265, -3.11695271, -3.09231277, -3.06767283, -3.04303288,
#        -3.01839294, -2.993753  , -2.96911306, -2.94447311, -2.91983317,
#        -2.89519323, -2.87055329, -2.84591335, -2.8212734 , -2.79663346,
#        -2.77199352, -2.74735358, -2.72271363, -2.69807369, -2.67343375,
#        -2.64879381, -2.62415386, -2.59951392, -2.57487398, -2.55023404,
#        -2.52559409, -2.50095415, -2.47631421, -2.45167427, -2.42703432,
#        -2.40239438, -2.37775444, -2.3531145 , -2.32847456, -2.30383461,
#        -2.27919467, -2.25455473, -2.22991479, -2.20527484, -2.1806349 ,
#        -2.15599496, -2.13135502, -2.10671507, -2.08207513, -2.05743519,
#        -2.03279525, -2.0081553 , -1.98351536, -1.95887542, -1.93423548,
#        -1.90959553, -1.88495559, -1.86031565, -1.83567571, -1.81103577,
#        -1.78639582, -1.76175588, -1.73711594, -1.712476  , -1.68783605,
#        -1.66319611, -1.63855617, -1.61391623, -1.58927628, -1.56463634,
#        -1.5399964 , -1.51535646, -1.49071651, -1.46607657, -1.44143663,
#        -1.41679669, -1.39215674, -1.3675168 , -1.34287686, -1.31823692,
#        -1.29359698, -1.26895703, -1.24431709, -1.21967715, -1.19503721,
#        -1.17039726, -1.14575732, -1.12111738, -1.09647744, -1.07183749,
#        -1.04719755, -1.02255761, -0.99791767, -0.97327772, -0.94863778,
#        -0.92399784, -0.8993579 , -0.87471795, -0.85007801, -0.82543807,
#        -0.80079813, -0.77615819, -0.75151824, -0.7268783 , -0.70223836,
#        -0.67759842, -0.65295847, -0.62831853, -0.60367859, -0.57903865,
#        -0.5543987 , -0.52975876, -0.50511882, -0.48047888, -0.45583893,
#        -0.43119899, -0.40655905, -0.38191911, -0.35727916, -0.33263922,
#        -0.30799928, -0.28335934, -0.2587194 , -0.23407945, -0.20943951,
#        -0.18479957, -0.16015963, -0.13551968, -0.11087974, -0.0862398 ,
#        -0.06159986, -0.03695991, -0.01231997,  0.01231997,  0.03695991,
#         0.06159986,  0.0862398 ,  0.11087974,  0.13551968,  0.16015963,
#         0.18479957,  0.20943951,  0.23407945,  0.2587194 ,  0.28335934,
#         0.30799928,  0.33263922,  0.35727916,  0.38191911,  0.40655905,
#         0.43119899,  0.45583893,  0.48047888,  0.50511882,  0.52975876,
#         0.5543987 ,  0.57903865,  0.60367859,  0.62831853,  0.65295847,
#         0.67759842,  0.70223836,  0.7268783 ,  0.75151824,  0.77615819,
#         0.80079813,  0.82543807,  0.85007801,  0.87471795,  0.8993579 ,
#         0.92399784,  0.94863778,  0.97327772,  0.99791767,  1.02255761,
#         1.04719755,  1.07183749,  1.09647744,  1.12111738,  1.14575732,
#         1.17039726,  1.19503721,  1.21967715,  1.24431709,  1.26895703,
#         1.29359698,  1.31823692,  1.34287686,  1.3675168 ,  1.39215674,
#         1.41679669,  1.44143663,  1.46607657,  1.49071651,  1.51535646,
#         1.5399964 ,  1.56463634,  1.58927628,  1.61391623,  1.63855617,
#         1.66319611,  1.68783605,  1.712476  ,  1.73711594,  1.76175588,
#         1.78639582,  1.81103577,  1.83567571,  1.86031565,  1.88495559,
#         1.90959553,  1.93423548,  1.95887542,  1.98351536,  2.0081553 ,
#         2.03279525,  2.05743519,  2.08207513,  2.10671507,  2.13135502,
#         2.15599496,  2.1806349 ,  2.20527484,  2.22991479,  2.25455473,
#         2.27919467,  2.30383461,  2.32847456,  2.3531145 ,  2.37775444,
#         2.40239438,  2.42703432,  2.45167427,  2.47631421,  2.50095415,
#         2.52559409,  2.55023404,  2.57487398,  2.59951392,  2.62415386,
#         2.64879381,  2.67343375,  2.69807369,  2.72271363,  2.74735358,
#         2.77199352,  2.79663346,  2.8212734 ,  2.84591335,  2.87055329,
#         2.89519323,  2.91983317,  2.94447311,  2.96911306,  2.993753  ,
#         3.01839294,  3.04303288,  3.06767283,  3.09231277,  3.11695271,
#         3.14159265])

# %%
x=np.linspace(-np.pi,np.pi,256)
y=np.cos(x)
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,1])
plt.show()

# %%
plt.plot(x,y)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$']) # 라텍스
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %%
# 여러개의 선 출력

# %%
t=np.arange(0,5,0.2)

# %%
plt.plot(t,t,'r--',   t,0.5*t**2,'bs:',  t,0.2*t**3,'g^-')
# Out:
# [<matplotlib.lines.Line2D at 0x2c8bdcf6b20>,
#  <matplotlib.lines.Line2D at 0x2c8bdcf6b50>,
#  <matplotlib.lines.Line2D at 0x2c8bdcf6c40>]

# %%
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")

# %%
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")

plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")

# %%
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r",
        label="blue")

plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c",
        label="black")
plt.legend(loc=2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2) # 1~10까지 있음
plt.xlabel("time")
plt.ylabel("amp")
plt.show()

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2)) # size 1: 72pixel 
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')

# %%
f1 = plt.figure(figsize=(5,4))
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')
f2=plt.gcf()
print(f2,id(f2))
# Out:
# Figure(360x288) 3061222287392

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
f1 = plt.figure(figsize=(10,6))

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
f1 = plt.figure(figsize=(10,6))

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 2, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 2, 4)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.352273x0.343182)
# AxesSubplot(0.547727,0.125;0.352273x0.343182)

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")
# Out:
# Text(0.5, 1.0, 'axes 4')

# %%
# subplots 명령으로 여러개의 axes를 동시에 생성

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %%
#https://matplotlib.org/2.0.2/api/pyplot_api.html

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

y = [2, 3, 1]
x = np.arange(len(y))
xlabel = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(y_pos, performance, xerr=error, alpha=0.4)
plt.yticks(y_pos, people)
plt.xlabel('x 라벨')
plt.show()
# xerr 인수나 yerr 인수를 지정하면 에러 바(error bar)를 추가할 수 있다.
# 다음 코드에서 alpha는 투명도를 지정한다. 0이면 완전 투명, 1이면 완전 불투명이다.

# %%
# 스템플롯
# 바 차트와 유사하지만 폭(width)이 없는 스템 플롯(stem plot)도 있다. 
# 주로 이산 확률 함수나 자기상관관계(auto-correlation)를 묘사할 때 사용된다.
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.')
plt.show()

# %%
# 파이차트
plt.axis('equal')
labels = ['개구리', '돼지', '개', '통나무']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('YryPL0GnfTc', width=800, height=450)

# %%
YouTubeVideo('ncfgAQ1542k', width=800, height=450)

# %%
# 버블차트
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %%
# Imshow
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3),
                         subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation='nearest', cmap='BrBG')
axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation='nearest', cmap='BrBG_r')
plt.show()

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %%
# 칸투어 플롯
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)


n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha=.75, cmap='jet')
plt.contour(XX, YY, ZZ, colors='black')
plt.show()

# %%
# 3D 서비피스 플롯

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()
